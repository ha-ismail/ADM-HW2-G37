# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# read taxi data for Jan 2018
data='yellow_tripdata_2018-01.csv'
yt_data = pd.read_csv(data)

# read zone lookup table
zones = 'taxi_zone_lookup.csv'
zonesLookup = pd.read_csv(zones)


# Merge the data with taxi zones table (taking only data we need for the QR#2)
yt_data_merged= yt_data[['tpep_pickup_datetime','passenger_count','PULocationID']].merge(zonesLookup[['LocationID','Borough']],how='inner', left_on='PULocationID', right_on='LocationID')

yt_data_merged
# Out:
#         tpep_pickup_datetime  passenger_count  PULocationID  LocationID  \
# 0        2018-01-01 00:21:05                1            41          41
# 1        2018-01-01 00:49:32                1            41          41
# 2        2018-01-01 00:11:56                2            41          41
# 3        2018-01-01 00:58:32                1            41          41
# 4        2018-01-01 00:14:09                1            41          41
# 5        2018-01-01 00:32:15                1            41          41
# 6        2018-01-01 00:38:34                5            41          41
# 7        2018-01-01 00:38:54                1            41          41
# 8        2018-01-01 00:28:06                3            41          41
# 9        2018-01-01 00:36:18                3            41          41
# 10       2018-01-01 00:50:29                2            41          41
# 11       2018-01-01 00:35:57                2            41          41
# 12       2018-01-01 00:44:14                6            41          41
# 13       2018-01-01 00:48:29                4            41          41
# 14       2018-01-01 00:21:32                1            41          41
# 15       2018-01-01 00:48:28                1            41          41
# 16       2018-01-01 00:47:55                1            41          41
# 17       2018-01-01 00:07:30                3            41          41
# 18       2018-01-01 00:14:29                1            41          41
# 19       2018-01-01 00:25:04                5            41          41
# 20       2018-01-01 00:04:04                2            41          41
# 21       2018-01-01 00:47:48                1            41          41
# 22       2018-01-01 00:17:35                5            41          41
# 23       2018-01-01 01:00:37                1            41          41
# 24       2018-01-01 00:51:38                6            41          41
# 25       2018-01-01 00:54:47                1            41          41
# 26       2018-01-01 00:45:16                1            41          41
# 27       2018-01-01 00:11:39                2            41          41
# 28       2018-01-01 00:50:15                2            41          41
# 29       2018-01-01 00:54:23                2            41          41
# ...                      ...              ...           ...         ...
# 8759844  2018-01-30 07:37:45                1           109         109
# 8759845  2018-01-30 07:42:55                1           109         109
# 8759846  2018-01-07 17:42:13                1           115         115
# 8759847  2018-01-12 11:49:06                1           115         115
# 8759848  2018-01-14 19:11:43                1           115         115
# 8759849  2018-01-14 19:43:24                2           115         115
# 8759850  2018-01-15 05:44:01                1           115         115
# 8759851  2018-01-19 21:19:30                5           115         115
# 8759852  2018-01-21 18:14:41                1           115         115
# 8759853  2018-01-07 18:02:56                1           184         184
# 8759854  2018-01-28 21:14:55                1           184         184
# 8759855  2018-01-07 20:20:39                1           245         245
# 8759856  2018-01-15 14:41:58                1           245         245
# 8759857  2018-01-18 08:53:36                1           245         245
# 8759858  2018-01-20 07:38:59                1           245         245
# 8759859  2018-01-25 00:06:23                1           245         245
# 8759860  2018-01-10 01:13:21                6           221         221
# 8759861  2018-01-13 02:02:35                1            27          27
# 8759862  2018-01-13 02:06:33                1            27          27
# 8759863  2018-01-16 22:03:55                7            27          27
# 8759864  2018-01-18 23:37:12                1            27          27
# 8759865  2018-01-27 00:33:55                2            27          27
# 8759866  2018-01-14 10:49:13                2           105         105
# 8759867  2018-01-14 11:54:00                1           105         105
# 8759868  2018-01-15 17:57:10                1           105         105
# 8759869  2018-01-20 18:26:03                1           105         105
# 8759870  2018-01-20 18:36:59                1           105         105
# 8759871  2018-01-20 23:31:09                1           105         105
# 8759872  2018-01-31 06:40:18                1           105         105
# 8759873  2018-01-25 00:30:29                1            44          44
#
#                Borough
# 0            Manhattan
# 1            Manhattan
# 2            Manhattan
# 3            Manhattan
# 4            Manhattan
# 5            Manhattan
# 6            Manhattan
# 7            Manhattan
# 8            Manhattan
# 9            Manhattan
# 10           Manhattan
# 11           Manhattan
# 12           Manhattan
# 13           Manhattan
# 14           Manhattan
# 15           Manhattan
# 16           Manhattan
# 17           Manhattan
# 18           Manhattan
# 19           Manhattan
# 20           Manhattan
# 21           Manhattan
# 22           Manhattan
# 23           Manhattan
# 24           Manhattan
# 25           Manhattan
# 26           Manhattan
# 27           Manhattan
# 28           Manhattan
# 29           Manhattan
# ...                ...
# 8759844  Staten Island
# 8759845  Staten Island
# 8759846  Staten Island
# 8759847  Staten Island
# 8759848  Staten Island
# 8759849  Staten Island
# 8759850  Staten Island
# 8759851  Staten Island
# 8759852  Staten Island
# 8759853          Bronx
# 8759854          Bronx
# 8759855  Staten Island
# 8759856  Staten Island
# 8759857  Staten Island
# 8759858  Staten Island
# 8759859  Staten Island
# 8759860  Staten Island
# 8759861         Queens
# 8759862         Queens
# 8759863         Queens
# 8759864         Queens
# 8759865         Queens
# 8759866      Manhattan
# 8759867      Manhattan
# 8759868      Manhattan
# 8759869      Manhattan
# 8759870      Manhattan
# 8759871      Manhattan
# 8759872      Manhattan
# 8759873  Staten Island
#
# [8759874 rows x 5 columns]

# %%
#del yt_data

qr2 = yt_data_merged[['tpep_pickup_datetime','passenger_count','Borough']]
# Get the hour from the pickup time column
#yt_qr1['tpep_pickup_datetime']=yt_qr1['tpep_pickup_datetime'].apply(lambda x: pd.core.tools.datetimes.to_datetime(x).hour)
#yt_qr1

# %%
qr2
# Out:
#         tpep_pickup_datetime  passenger_count        Borough
# 0        2018-01-01 00:21:05                1      Manhattan
# 1        2018-01-01 00:49:32                1      Manhattan
# 2        2018-01-01 00:11:56                2      Manhattan
# 3        2018-01-01 00:58:32                1      Manhattan
# 4        2018-01-01 00:14:09                1      Manhattan
# 5        2018-01-01 00:32:15                1      Manhattan
# 6        2018-01-01 00:38:34                5      Manhattan
# 7        2018-01-01 00:38:54                1      Manhattan
# 8        2018-01-01 00:28:06                3      Manhattan
# 9        2018-01-01 00:36:18                3      Manhattan
# 10       2018-01-01 00:50:29                2      Manhattan
# 11       2018-01-01 00:35:57                2      Manhattan
# 12       2018-01-01 00:44:14                6      Manhattan
# 13       2018-01-01 00:48:29                4      Manhattan
# 14       2018-01-01 00:21:32                1      Manhattan
# 15       2018-01-01 00:48:28                1      Manhattan
# 16       2018-01-01 00:47:55                1      Manhattan
# 17       2018-01-01 00:07:30                3      Manhattan
# 18       2018-01-01 00:14:29                1      Manhattan
# 19       2018-01-01 00:25:04                5      Manhattan
# 20       2018-01-01 00:04:04                2      Manhattan
# 21       2018-01-01 00:47:48                1      Manhattan
# 22       2018-01-01 00:17:35                5      Manhattan
# 23       2018-01-01 01:00:37                1      Manhattan
# 24       2018-01-01 00:51:38                6      Manhattan
# 25       2018-01-01 00:54:47                1      Manhattan
# 26       2018-01-01 00:45:16                1      Manhattan
# 27       2018-01-01 00:11:39                2      Manhattan
# 28       2018-01-01 00:50:15                2      Manhattan
# 29       2018-01-01 00:54:23                2      Manhattan
# ...                      ...              ...            ...
# 8759844  2018-01-30 07:37:45                1  Staten Island
# 8759845  2018-01-30 07:42:55                1  Staten Island
# 8759846  2018-01-07 17:42:13                1  Staten Island
# 8759847  2018-01-12 11:49:06                1  Staten Island
# 8759848  2018-01-14 19:11:43                1  Staten Island
# 8759849  2018-01-14 19:43:24                2  Staten Island
# 8759850  2018-01-15 05:44:01                1  Staten Island
# 8759851  2018-01-19 21:19:30                5  Staten Island
# 8759852  2018-01-21 18:14:41                1  Staten Island
# 8759853  2018-01-07 18:02:56                1          Bronx
# 8759854  2018-01-28 21:14:55                1          Bronx
# 8759855  2018-01-07 20:20:39                1  Staten Island
# 8759856  2018-01-15 14:41:58                1  Staten Island
# 8759857  2018-01-18 08:53:36                1  Staten Island
# 8759858  2018-01-20 07:38:59                1  Staten Island
# 8759859  2018-01-25 00:06:23                1  Staten Island
# 8759860  2018-01-10 01:13:21                6  Staten Island
# 8759861  2018-01-13 02:02:35                1         Queens
# 8759862  2018-01-13 02:06:33                1         Queens
# 8759863  2018-01-16 22:03:55                7         Queens
# 8759864  2018-01-18 23:37:12                1         Queens
# 8759865  2018-01-27 00:33:55                2         Queens
# 8759866  2018-01-14 10:49:13                2      Manhattan
# 8759867  2018-01-14 11:54:00                1      Manhattan
# 8759868  2018-01-15 17:57:10                1      Manhattan
# 8759869  2018-01-20 18:26:03                1      Manhattan
# 8759870  2018-01-20 18:36:59                1      Manhattan
# 8759871  2018-01-20 23:31:09                1      Manhattan
# 8759872  2018-01-31 06:40:18                1      Manhattan
# 8759873  2018-01-25 00:30:29                1  Staten Island
#
# [8759874 rows x 3 columns]

# %%
from datetime import datetime
# Getting the hour from the pickup time
qr2.iloc[:,0] = qr2.iloc[:,0].apply(lambda x: pd.to_datetime(x).hour)
# Out:
# /Users/ismail/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
qr2
# Out:
#          tpep_pickup_datetime  passenger_count        Borough
# 0                           0                1      Manhattan
# 1                           0                1      Manhattan
# 2                           0                2      Manhattan
# 3                           0                1      Manhattan
# 4                           0                1      Manhattan
# 5                           0                1      Manhattan
# 6                           0                5      Manhattan
# 7                           0                1      Manhattan
# 8                           0                3      Manhattan
# 9                           0                3      Manhattan
# 10                          0                2      Manhattan
# 11                          0                2      Manhattan
# 12                          0                6      Manhattan
# 13                          0                4      Manhattan
# 14                          0                1      Manhattan
# 15                          0                1      Manhattan
# 16                          0                1      Manhattan
# 17                          0                3      Manhattan
# 18                          0                1      Manhattan
# 19                          0                5      Manhattan
# 20                          0                2      Manhattan
# 21                          0                1      Manhattan
# 22                          0                5      Manhattan
# 23                          1                1      Manhattan
# 24                          0                6      Manhattan
# 25                          0                1      Manhattan
# 26                          0                1      Manhattan
# 27                          0                2      Manhattan
# 28                          0                2      Manhattan
# 29                          0                2      Manhattan
# ...                       ...              ...            ...
# 8759844                     7                1  Staten Island
# 8759845                     7                1  Staten Island
# 8759846                    17                1  Staten Island
# 8759847                    11                1  Staten Island
# 8759848                    19                1  Staten Island
# 8759849                    19                2  Staten Island
# 8759850                     5                1  Staten Island
# 8759851                    21                5  Staten Island
# 8759852                    18                1  Staten Island
# 8759853                    18                1          Bronx
# 8759854                    21                1          Bronx
# 8759855                    20                1  Staten Island
# 8759856                    14                1  Staten Island
# 8759857                     8                1  Staten Island
# 8759858                     7                1  Staten Island
# 8759859                     0                1  Staten Island
# 8759860                     1                6  Staten Island
# 8759861                     2                1         Queens
# 8759862                     2                1         Queens
# 8759863                    22                7         Queens
# 8759864                    23                1         Queens
# 8759865                     0                2         Queens
# 8759866                    10                2      Manhattan
# 8759867                    11                1      Manhattan
# 8759868                    17                1      Manhattan
# 8759869                    18                1      Manhattan
# 8759870                    18                1      Manhattan
# 8759871                    23                1      Manhattan
# 8759872                     6                1      Manhattan
# 8759873                     0                1  Staten Island
#
# [8759874 rows x 3 columns]

# %%
qr2[['tpep_pickup_datetime','passenger_count']].groupby('tpep_pickup_datetime').sum()
# Out:
#                       passenger_count
# tpep_pickup_datetime
# 0                              429109
# 1                              312717
# 2                              235747
# 3                              170417
# 4                              130610
# 5                              133693
# 6                              298468
# 7                              519907
# 8                              653514
# 9                              656432
# 10                             643123
# 11                             669669
# 12                             715195
# 13                             721008
# 14                             769086
# 15                             792578
# 16                             743710
# 17                             832747
# 18                             925679
# 19                             879398
# 20                             778626
# 21                             777789
# 22                             722042
# 23                             564586

# %%
fig, ax = plt.subplots(figsize=(15,7))
# Modify the x-axis to show numbers between 0-23
plt.xticks(list(range(24)))
qr2[['tpep_pickup_datetime','passenger_count']].groupby('tpep_pickup_datetime').sum().plot(ax=ax,kind="line")

# %%
'''
    Visualizing the number of passenger per hour in NY, we notice:
    the peak of number of passengers is at 18, it decreases at 4-5 morning, 
    and start increasing sharply until 8 (workers and students time), 
    after that it has a normal increase un til it reaches the peak at 18 
    and then starts decreasing until reaching the lowest at 4am.
    
'''

# %%
# Group by time slots and Borough and calculate the mean of passengers
qr2[['tpep_pickup_datetime','passenger_count','Borough']].groupby(['tpep_pickup_datetime','Borough'])['passenger_count'].sum()
#qr2[['tpep_pickup_datetime','passenger_count','Borough']].groupby(['Borough','tpep_pickup_datetime']).['passenger_count'].sum()
# Out:
# tpep_pickup_datetime  Borough
# 0                     Bronx               433
#                       Brooklyn          10290
#                       EWR                   2
#                       Manhattan        381264
#                       Queens            29784
#                       Staten Island        10
#                       Unknown            7326
# 1                     Bronx               409
#                       Brooklyn           8470
#                       EWR                   2
#                       Manhattan        283047
#                       Queens            15219
#                       Staten Island         9
#                       Unknown            5561
# 2                     Bronx               421
#                       Brooklyn           6793
#                       EWR                   2
#                       Manhattan        215088
#                       Queens             9304
#                       Staten Island         5
#                       Unknown            4134
# 3                     Bronx               356
#                       Brooklyn           5285
#                       EWR                   8
#                       Manhattan        154794
#                       Queens             6887
#                       Staten Island        11
#                       Unknown            3076
# 4                     Bronx               448
#                       Brooklyn           4493
#                                         ...
# 19                    Queens            50985
#                       Staten Island        19
#                       Unknown           13992
# 20                    Bronx               315
#                       Brooklyn           6944
#                       EWR                  29
#                       Manhattan        709023
#                       Queens            49889
#                       Staten Island        13
#                       Unknown           12413
# 21                    Bronx               338
#                       Brooklyn           8279
#                       EWR                  31
#                       Manhattan        701035
#                       Queens            55677
#                       Staten Island        14
#                       Unknown           12415
# 22                    Bronx               333
#                       Brooklyn          10651
#                       EWR                   1
#                       Manhattan        651388
#                       Queens            48031
#                       Staten Island         7
#                       Unknown           11631
# 23                    Bronx               447
#                       Brooklyn          11285
#                       Manhattan        502227
#                       Queens            41255
#                       Staten Island         5
#                       Unknown            9367
# Name: passenger_count, Length: 166, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
# Modify the x-axis to show numbers between 0-23
plt.xticks(list(range(24)))
qr2[['tpep_pickup_datetime','passenger_count','Borough']].groupby(['tpep_pickup_datetime','Borough'])['passenger_count'].sum().unstack().plot(ax=ax)
#qr2[['tpep_pickup_datetime','passenger_count','Borough']].groupby(['tpep_pickup_datetime','Borough'])['passenger_count'].mean().unstack().plot(ax=ax)

# %%
''' THE BELOW COMMENTS ARE OLD! (USED FOR mean INSTEAD OF sum)
    We notice the differences among the boroughs in term of most passengers per slot (time of pickup)
    - Bronx: the average of passengers has a small peak at 13 (from 12 tp 15)
    - Brooklyn: the average is somehow stable, with a tiny peak at 7
    - EWR: the average of passengers varies per time, it has peaks at midnight, 4, and 12
    - Manhattan: the average is somehow stable with tiny increase from midnight until 4
    - Queens: the average is somehow stable
    - Staten Island: the average of passengers varies sharply, it has peaks at 1, 8, 13, 15, 23 and the top peak at 17 (we notice some missed data at 6)

# %%
'''
    The above Analysis was only for Jan 2018, in order to get the full image of the whole period provided,
    We need to do the same steps for each month and get the 
'''
